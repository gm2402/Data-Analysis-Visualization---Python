# %% [markdown]
# # Gautam Mishra

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# Numpy-Numerical Python that Deals with numbers.
#
# Pandas-Used to analyse data.It has functions for analyzing,cleaning,exploring and manipulating Data.
#
# Matplotlib-comprehensive library for creating static, animated, and interactive visualizations.
#
# Seaborn-Seaborn is a Python data visualization library based on matplotlib. It provides a high-level
# interface for drawing attractive and informative statistical graphics.
#
# Warnings are provided to warn the developer of situations that aren’t necessarily exceptions
# and ignore them.

# %%
df=pd.read_csv('supermarket_sales .csv')

# %% [markdown]
# Here,we are reading the csv file and storing it in df variable.

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# The above data contains 1000 rows and 17 columns,With sales information.

# %% [markdown]
# # Q1.Show first 5 records of dataset?

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# head() function gives top five record from data

# %% [markdown]
# # Q2.How many records and columns are in dataset?

# %%
df.shape
# Out:
# (1000, 17)

# %% [markdown]
# This Data contains 1000 Rows and 17 columns.

# %% [markdown]
# # Q3.Show the datatypes of different columns.handle the missing values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %% [markdown]
# This datatype contains 8 Numerical column and 9 Object column.
# There are no null values.

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# # Q4.What was the total number of sales? What branch has the highest number of sales?

# %%
df['Quantity'].sum()
# Out:
# 5510

# %% [markdown]
# The total number of sales is 5510.

# %%
df.groupby('Branch')['Quantity'].sum()
# Out:
# Branch
# A    1859
# B    1820
# C    1831
# Name: Quantity, dtype: int64

# %% [markdown]
# Branch 'A' has highest number of sales.

# %% [markdown]
# # Q5.What type of product is sold the most?

# %%
df.groupby('Product line')['Quantity'].sum()
# Out:
# Product line
# Electronic accessories    971
# Fashion accessories       902
# Food and beverages        952
# Health and beauty         854
# Home and lifestyle        911
# Sports and travel         920
# Name: Quantity, dtype: int64

# %% [markdown]
# "Electronics accessories" types of products are sold most.

# %% [markdown]
# # Q6.What is the average sales of electoniv=cs accessories?

# %%
df[df['Product line']=='Electronic accessories']['Quantity'].mean()
# Out:
# 5.711764705882353

# %% [markdown]
# The Average Sales of electronics accessories is 5.

# %% [markdown]
# # Q7.What gender buy more items in each category? what is the category?

# %%
df.groupby('Product line')['Gender'].value_counts()
# Out:
# Product line            Gender
# Electronic accessories  Male      86
#                         Female    84
# Fashion accessories     Female    96
#                         Male      82
# Food and beverages      Female    90
#                         Male      84
# Health and beauty       Male      88
#                         Female    64
# Home and lifestyle      Male      81
#                         Female    79
# Sports and travel       Female    88
#                         Male      78
# Name: Gender, dtype: int64

# %% [markdown]
# In Accessories like Electronics,Health and Beauty,Home and lifestyle Male buy's more items.
# And in accessories like Fashion,Food and Beverages, Sports and travel female buy's more items.

# %% [markdown]
# # Q8.What is the favorite method of payment of the members? of the normal customers?

# %%
df[df['Customer type']=='Normal']['Payment'].value_counts()
# Out:
# Ewallet        184
# Cash           176
# Credit card    139
# Name: Payment, dtype: int64

# %% [markdown]
# The favorite method of payment of normal customers is 'Ewallet'

# %% [markdown]
# # Q9.What time should we display an advertisement to maximize the revenue?

# %%
df['Time'].mode()
# Out:
# 0    14:42
# 1    19:48
# Name: Time, dtype: object

# %% [markdown]
# To maximize the revenue we should display advertisement between 14:30 to 15:00 at afternoon and 19:30 to 20:00 in the evening

# %% [markdown]
# # Q10.What does the customer rating look like and is it skewed?

# %%
sns.distplot(df['Rating'])
df['Rating'].skew()
# Out:
# 0.00900964876573073

# %% [markdown]
# 'No',customer rating is not skewed, it  looks like a bell shaped and it is normally distributed.

# %% [markdown]
# # Q11.Does gross income affect the ratings that the customers provide?

# %%
sns.scatterplot(df['gross income'],df['Rating'])
# Out:
# <AxesSubplot:xlabel='gross income', ylabel='Rating'>

# %% [markdown]
# NO,the gross income does not affect the ratings.

# %% [markdown]
# # Q12.Is there any relationship between Gender and Gross income?

# %%
sns.stripplot(df['Gender'],df['gross income'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='gross income'>

# %% [markdown]
# No,There is no relation between Gender and Gross income

# %% [markdown]
# # Q13.What is the spending pattern of females and males and in which category do they spend a lot?

# %%
df.groupby('Gender')['Product line'].value_counts()
# Out:
# Gender  Product line
# Female  Fashion accessories       96
#         Food and beverages        90
#         Sports and travel         88
#         Electronic accessories    84
#         Home and lifestyle        79
#         Health and beauty         64
# Male    Health and beauty         88
#         Electronic accessories    86
#         Food and beverages        84
#         Fashion accessories       82
#         Home and lifestyle        81
#         Sports and travel         78
# Name: Product line, dtype: int64

# %% [markdown]
# Females mostly spends on Fashion accessories and male mostly spends on health and beauty.

# %%
plt.figure(figsize=(10,8))
sns.countplot(hue=df['Gender'],x=df['Product line'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Q14.Analyze the pairwise relationship between the numeric variables?

# %%
sns.pairplot(df)

# %% [markdown]
# Pairplot diagonally it shows histplot- Counts of data and shows data distribution
# Off-diagonally it shows scatterplot-relation between 2 Numerical variable.
