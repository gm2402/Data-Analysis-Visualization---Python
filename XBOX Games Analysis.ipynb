# %% [markdown]
# # XBOX GAMES PROJECT

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Reading the Video_Games_Sale.csv file and printing first 5 records using head() function
# Read function is used to read the cvs data file.Head Function is used to print first 5 records from the dataset.

# %%
df=pd.read_csv("Video_Games_Sale.csv")
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %% [markdown]
# # Printing first 10 records of dataset using head() function
# #You can mention the number of rows in the head function bracket.It will give you mentioned number of rows from top.

# %%
df.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53
# ...

# %% [markdown]
# # Printing last 5 records using tail() function
# # tail() function gives last five records from bottom

# %%
df.tail()
# Out:
#                                 Name Platform  Year_of_Release       Genre  \
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0      Action
# 16715               LMA Manager 2007     X360           2006.0      Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0   Adventure
# 16717               Spirits & Spells      GBA           2003.0    Platform
# 16718            Winning Post 8 2016      PSV           2016.0  Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 16714    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
# 16715   Codemasters      0.00      0.01      0.00          0.0          0.01
# 16716  Idea Factory      0.00      0.00      0.01          0.0          0.01
# 16717       Wanadoo      0.01      0.00      0.00          0.0          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
#
# ...

# %% [markdown]
# # Printing last 10 records using tail() function
# #You can mention the index in the tail function bracket. It will give mentioned number of rows from bottom.

# %%
df.tail(10)
# Out:
#                                                    Name Platform  \
# 16709                                           15 Days       PC
# 16710                     Men in Black II: Alien Escape       GC
# 16711                                  Aiyoku no Eustia      PSV
# 16712                Woody Woodpecker in Crazy Castle 5      GBA
# 16713  SCORE International Baja 1000: The Official Game      PS2
# 16714                     Samurai Warriors: Sanada Maru      PS3
# 16715                                  LMA Manager 2007     X360
# 16716                           Haitaka no Psychedelica      PSV
# 16717                                  Spirits & Spells      GBA
# 16718                               Winning Post 8 2016      PSV
#
#        Year_of_Release       Genre          Publisher  NA_Sales  EU_Sales  \
# 16709           2009.0   Adventure  DTP Entertainment      0.00      0.01
# 16710           2003.0     Shooter         Infogrames      0.01      0.00
# ...

# %% [markdown]
# # Printing any random five rows of the dataset using sample function.
# #You can mention the count of random rows in the bracket.

# %%
df.sample(5)
# Out:
#                                        Name Platform  Year_of_Release  \
# 11344       Harvey Birdman: Attorney at Law      Wii           2008.0
# 5258                             Suikoden V      PS2           2006.0
# 7571                We Sing Robbie Williams      Wii           2010.0
# 7583          DarkStar One: Broken Alliance     X360           2010.0
# 13631  Katekyoo Hitman Reborn! Battle Arena      PSP           2008.0
#
#               Genre                     Publisher  NA_Sales  EU_Sales  \
# 11344     Adventure                        Capcom      0.08      0.00
# 5258   Role-Playing  Konami Digital Entertainment      0.08      0.06
# 7571           Misc                  Nordic Games      0.00      0.18
# 7583     Simulation                 Kalypso Media      0.11      0.07
# 13631      Fighting         Marvelous Interactive      0.00      0.00
#
#        JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# ...

# %% [markdown]
# # Finding the Number of counts, Mean, Standard Deviation, Minimum value, Lower quartile, Median, Upper quartile, Maximum value of all columns in dataset.
# #Describe() function is used to get the description of data in the dataframe.

# %%
df.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count   User_Score  \
# count  16719.000000  16719.000000   8137.000000   8137.000000  7590.000000
# mean       0.047332      0.533543     68.967679     26.360821     7.125046
# std        0.186710      1.547935     13.938165     18.980495     1.500006
# min        0.000000      0.010000     13.000000      3.000000     0.000000
# ...

# %% [markdown]
# # Finding Global_Sales Column Mean, Standard deviation, Number of values, Median, Minimum, Maximum, Upper and Lower quantile.
# #It is used to get the description of particular column in the dataframe.
# #In below example Global_Sales is the column name.

# %%
df.Global_Sales.describe()
# Out:
# count    16719.000000
# mean         0.533543
# std          1.547935
# min          0.010000
# 25%          0.060000
# 50%          0.170000
# 75%          0.470000
# max         82.530000
# Name: Global_Sales, dtype: float64

# %% [markdown]
# # Info function is used to find basic information about the dataset. #
# #The total number of rows are 16719 and columns are 16 in the dataset.
# #The categorical columns are 6 and numercial columns are 10.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       7590 non-null   float64
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# ...

# %% [markdown]
# # Finding total number of null values column wise.
# #The highets number of null values are in the User_Score, User_Count columns which is 9129

# %%
df.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         9129
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %% [markdown]
# # Finding percenatge of null values column wise

# %%
df.isnull().sum()/len(df)*100
# Out:
# Name                0.011962
# Platform            0.000000
# Year_of_Release     1.608948
# Genre               0.011962
# Publisher           0.322986
# NA_Sales            0.000000
# EU_Sales            0.000000
# JP_Sales            0.000000
# Other_Sales         0.000000
# Global_Sales        0.000000
# Critic_Score       51.330821
# Critic_Count       51.330821
# User_Score         54.602548
# User_Count         54.602548
# Developer          39.613613
# Rating             40.486871
# dtype: float64

# %% [markdown]
# # Droping columns with null values

# %%
df.drop(['Critic_Score','Critic_Count'],axis=1,inplace=True)
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
df.head()

# %% [markdown]
# # Finding count of duplicates in a particulat column(Column:Name)

# %%
df.Name.value_counts()
# Out:
# Need for Speed: Most Wanted                         12
# FIFA 14                                              9
# Ratatouille                                          9
# LEGO Marvel Super Heroes                             9
# Madden NFL 07                                        9
#                                                     ..
# Jewels of the Tropical Lost Island                   1
# Sherlock Holmes and the Mystery of Osborne House     1
# The King of Fighters '95 (CD)                        1
# Megamind: Mega Team Unite                            1
# Haitaka no Psychedelica                              1
# Name: Name, Length: 11562, dtype: int64

# %% [markdown]
# # Finding all columns names of dataset

# %%
df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %% [markdown]
# # Coverting float (Continous decimal no.) numerical values into integer (Discrete whole no.) values for the column JP_Sales

# %%
df["JP_Sales"]=df["JP_Sales"].astype("int")

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96         3         8.45         82.53          76.0
# 1     29.08      3.58         6         0.77         40.24           NaN
# 2     15.68     12.76         3         3.29         35.52          82.0
# 3     15.61     10.93         3         2.95         32.77          80.0
# 4     11.27      8.89        10         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %% [markdown]
# # Finding all numerical columns of dataset

# %%
df.select_dtypes(include=['int','float'])
# Out:
#        Year_of_Release  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0               2006.0     41.36     28.96         3         8.45
# 1               1985.0     29.08      3.58         6         0.77
# 2               2008.0     15.68     12.76         3         3.29
# 3               2009.0     15.61     10.93         3         2.95
# 4               1996.0     11.27      8.89        10         1.00
# ...                ...       ...       ...       ...          ...
# 16714           2016.0      0.00      0.00         0         0.00
# 16715           2006.0      0.00      0.01         0         0.00
# 16716           2016.0      0.00      0.00         0         0.00
# 16717           2003.0      0.01      0.00         0         0.00
# 16718           2016.0      0.00      0.00         0         0.00
#
#        Global_Sales  Critic_Score  Critic_Count  User_Score  User_Count
# 0             82.53          76.0          51.0         8.0       322.0
# ...

# %% [markdown]
# # Finding all categorical columns of dataset

# %%
df.select_dtypes(include=['object'])
# Out:
#                                 Name Platform         Genre     Publisher  \
# 0                         Wii Sports      Wii        Sports      Nintendo
# 1                  Super Mario Bros.      NES      Platform      Nintendo
# 2                     Mario Kart Wii      Wii        Racing      Nintendo
# 3                  Wii Sports Resort      Wii        Sports      Nintendo
# 4           Pokemon Red/Pokemon Blue       GB  Role-Playing      Nintendo
# ...                              ...      ...           ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3        Action    Tecmo Koei
# 16715               LMA Manager 2007     X360        Sports   Codemasters
# 16716        Haitaka no Psychedelica      PSV     Adventure  Idea Factory
# 16717               Spirits & Spells      GBA      Platform       Wanadoo
# 16718            Winning Post 8 2016      PSV    Simulation    Tecmo Koei
#
#       Developer Rating
# 0      Nintendo      E
# 1           NaN    NaN
# ...

# %% [markdown]
# # Finding total number of unique values from Genre column

# %%
df['Genre'].nunique()
# Out:
# 12

# %% [markdown]
# # Finding total number of toys sold as per Genre.
# #Action toys has the highest number of sales

# %%
df['Genre'].value_counts()
# Out:
# Action          3370
# Sports          2348
# Misc            1750
# Role-Playing    1500
# Shooter         1323
# Adventure       1303
# Racing          1249
# Platform         888
# Simulation       874
# Fighting         849
# Strategy         683
# Puzzle           580
# Name: Genre, dtype: int64

# %%
plt.figure(figsize=(15,10))
plt.ylabel("TOYS SOLD")
plt.title("Yearly Global sales as per Genre")
B=df.groupby("Genre")["Global_Sales"].count().sort_values(ascending=False).plot(kind="bar")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.pairplot(df)
plt.show()

# %%
sns.countplot(df.Global_Sales)
# Out:
# <AxesSubplot:xlabel='Global_Sales', ylabel='count'>

# %% [markdown]
# # Using pie plot to show which type of toys sales was more.
# #Analysis:The Action toys where the highest sold product with the percentage of 20.2% of total sales.

# %%
plt.figure(figsize=(10,10))
df['Genre'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %% [markdown]
# # Finding first six rows for Name and Global_Sales column using loc function
# #loc is ised to find out rows by slicing and columns by column name

# %%
df.loc[0:5,['Name','Global_Sales']]
# Out:
#                        Name  Global_Sales
# 0                Wii Sports         82.53
# 1         Super Mario Bros.         40.24
# 2            Mario Kart Wii         35.52
# 3         Wii Sports Resort         32.77
# 4  Pokemon Red/Pokemon Blue         31.37
# 5                    Tetris         30.26

# %% [markdown]
# # Finding first six rows from Name column to Genre column using iloc function
# #iloc is ised to find out rows and columns by slicing

# %%
df.iloc[0:6,0:4]
# Out:
#                        Name Platform  Year_of_Release         Genre
# 0                Wii Sports      Wii           2006.0        Sports
# 1         Super Mario Bros.      NES           1985.0      Platform
# 2            Mario Kart Wii      Wii           2008.0        Racing
# 3         Wii Sports Resort      Wii           2009.0        Sports
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                    Tetris       GB           1989.0        Puzzle

# %% [markdown]
# # Finding mean median minimum and maximum value for the European Union Sales column

# %%
df['EU_Sales'].mean()
# Out:
# 0.14502482205873557

# %%
df['EU_Sales'].median()
# Out:
# 0.02

# %%
df['EU_Sales'].min()
# Out:
# 0.0

# %%
df['EU_Sales'].max()
# Out:
# 28.96

# %% [markdown]
# # Arranging dataset records as per the ascending order of the "Year_of_Release" column.
# #Sort_values is used to sort values in ascending or descending order for a particular column.

# %%
c=df.sort_values(by="Year_of_Release")
c.head(15)
# Out:
#                       Name Platform  Year_of_Release     Genre  \
# 262              Asteroids     2600           1980.0   Shooter
# 5360               Freeway     2600           1980.0    Action
# 546        Missile Command     2600           1980.0   Shooter
# 2650                Boxing     2600           1980.0  Fighting
# 4019            Ice Hockey     2600           1980.0    Sports
# 6301                Bridge     2600           1980.0      Misc
# 1764               Kaboom!     2600           1980.0      Misc
# 6876              Checkers     2600           1980.0      Misc
# 1968              Defender     2600           1980.0      Misc
# 4123            Grand Prix     2600           1981.0    Racing
# 5997             Fast Food     2600           1981.0    Action
# 240               Pitfall!     2600           1981.0  Platform
# 7881  International Soccer     2600           1981.0    Sports
# 8459          Armor Ambush     2600           1981.0    Action
# ...

# %% [markdown]
# # Sorting all the columns by their column names in ascending order
# Sort_index(axis=1) is used to sort columns by column names in ascending order

# %%
c=df.sort_index(axis=1)
c.head(15)
# Out:
#     Critic_Count  Critic_Score            Developer  EU_Sales         Genre  \
# 0           51.0          76.0             Nintendo     28.96        Sports
# 1            NaN           NaN                  NaN      3.58      Platform
# 2           73.0          82.0             Nintendo     12.76        Racing
# 3           73.0          80.0             Nintendo     10.93        Sports
# 4            NaN           NaN                  NaN      8.89  Role-Playing
# 5            NaN           NaN                  NaN      2.26        Puzzle
# 6           65.0          89.0             Nintendo      9.14      Platform
# 7           41.0          58.0             Nintendo      9.18          Misc
# 8           80.0          87.0             Nintendo      6.94      Platform
# 9            NaN           NaN                  NaN      0.63       Shooter
# 10           NaN           NaN                  NaN     10.95    Simulation
# ...

# %% [markdown]
# # Finding which year made how much gobal sales using grouby function

# %%
df.groupby("Year_of_Release")['Global_Sales'].sum()
# Out:
# Year_of_Release
# 1980.0     11.38
# 1981.0     35.77
# 1982.0     28.86
# 1983.0     16.79
# 1984.0     50.36
# 1985.0     53.94
# 1986.0     37.07
# 1987.0     21.74
# 1988.0     47.22
# 1989.0     73.45
# 1990.0     49.39
# 1991.0     32.23
# 1992.0     76.17
# 1993.0     48.40
# 1994.0     79.18
# 1995.0     88.11
# 1996.0    199.15
# 1997.0    200.98
# 1998.0    256.45
# 1999.0    251.25
# 2000.0    201.58
# 2001.0    331.47
# 2002.0    395.51
# 2003.0    357.80
# 2004.0    419.05
# 2005.0    458.31
# 2006.0    518.22
# 2007.0    605.37
# 2008.0    671.79
# 2009.0    658.88
# 2010.0    590.59
# 2011.0    507.79
# 2012.0    355.84
# 2013.0    361.24
# 2014.0    331.51
# 2015.0    268.05
# 2016.0    130.10
# 2017.0      0.06
# 2020.0      0.29
# Name: Global_Sales, dtype: float64

# %% [markdown]
# # Finding the Global sales per year using the column "Year_of_Release" and "Global_Sales" from Bar Plot
# #The highest global sales was in the year 2008.

# %%
plt.figure(figsize=(15,10))
plt.ylabel("Crores")
plt.title("Global sales per year")
df.groupby("Year_of_Release")['Global_Sales'].sum().plot(kind='bar')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.histplot(df["Global_Sales"],edgecolor="white",bins=6)
plt.ylabel("Billion Dollars")
plt.title("Global sales per year")
plt.show()

# %%
df.Global_Sales.describe()
# Out:
# count    16719.000000
# mean         0.533543
# std          1.547935
# min          0.010000
# 25%          0.060000
# 50%          0.170000
# 75%          0.470000
# max         82.530000
# Name: Global_Sales, dtype: float64

# %% [markdown]
# # Finding the sales columns of all Sports toys

# %%
df[df['Genre']=='Sports']
# Out:
#                                 Name Platform  Year_of_Release   Genre  \
# 0                         Wii Sports      Wii           2006.0  Sports
# 3                  Wii Sports Resort      Wii           2009.0  Sports
# 13                           Wii Fit      Wii           2007.0  Sports
# 15                      Wii Fit Plus      Wii           2009.0  Sports
# 77                           FIFA 16      PS4           2015.0  Sports
# ...                              ...      ...              ...     ...
# 16680               G1 Jockey 4 2008      PS3           2008.0  Sports
# 16692  Outdoors Unleashed: Africa 3D      3DS           2011.0  Sports
# 16697              PGA European Tour      N64           2000.0  Sports
# 16704       Mezase!! Tsuri Master DS       DS           2009.0  Sports
# 16715               LMA Manager 2007     X360           2006.0  Sports
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %% [markdown]
# # Countplot

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['Genre'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Filling null values of Critic_Score column with zeros

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96         3         8.45         82.53          76.0
# 1     29.08      3.58         6         0.77         40.24           NaN
# 2     15.68     12.76         3         3.29         35.52          82.0
# 3     15.61     10.93         3         2.95         32.77          80.0
# 4     11.27      8.89        10         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %%
df["Critic_Score"]=df["Critic_Score"].fillna(0)

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96         3         8.45         82.53          76.0
# 1     29.08      3.58         6         0.77         40.24           0.0
# 2     15.68     12.76         3         3.29         35.52          82.0
# 3     15.61     10.93         3         2.95         32.77          80.0
# 4     11.27      8.89        10         1.00         31.37           0.0
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %% [markdown]
# # Scatterplot

# %%
sns.scatterplot(df['EU_Sales'],df['Global_Sales'])
# Out:
# <AxesSubplot:xlabel='EU_Sales', ylabel='Global_Sales'>

# %% [markdown]
# # HeatMap
# #North american sales has the highwst contibution of 94 percent as compared to other countires in Global sales.

# %%
corr=df.corr()
sns.heatmap(corr,annot=True,fmt=".0%")
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Finding total Toys sales of Action Category in North America.
# #The Action Category toys total sales was of 879.01 Crores in North America.

# %%
M=df.groupby("Genre")

# %%
N=M.get_group("Action")["NA_Sales"].sum()
N
# Out:
# 879.01

# %% [markdown]
# # Finding total Toys sales of Racing Category in European Union.
# #The Racing Category toys total sales was of 236.50 Crores in European Union.

# %%
df[df["Genre"]=="Racing"]["EU_Sales"].sum()
# Out:
# 236.50999999999996

# %% [markdown]
# # Finding toys name with User score between 7(good) to 10(excellent)
# #There are 4890 toys out of 16717 toys which has an User Score(Rating) between 7 to 10

# %%
a=df[(df['User_Score']>=7.0)&(df['User_Score']<=10)][['Name','User_Score']]
a
# Out:
#                                     Name  User_Score
# 0                             Wii Sports         8.0
# 2                         Mario Kart Wii         8.3
# 3                      Wii Sports Resort         8.0
# 6                  New Super Mario Bros.         8.5
# 8              New Super Mario Bros. Wii         8.4
# ...                                  ...         ...
# 16665                    Bookworm Deluxe         8.0
# 16677     Mortal Kombat: Deadly Alliance         8.8
# 16685                            Worms 2         8.1
# 16696  Metal Gear Solid V: Ground Zeroes         7.6
# 16706            STORM: Frontline Nation         7.2
#
# [4890 rows x 2 columns]

# %%
a.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 4890 entries, 0 to 16706
# Series name: Name
# Non-Null Count  Dtype
# --------------  -----
# 4890 non-null   object
# dtypes: object(1)
# memory usage: 76.4+ KB

# %% [markdown]
# # Finding toys name with User score equal to or greater than 7(good) for the year 2016
# #There are 135 toys in th year 2016 which has an User Score(Rating) equal to or greater than 7.

# %%
r=df[(df['User_Score']>=7)&(df['Year_of_Release']==2016)][['Name','User_Score']]
r
# Out:
#                              Name  User_Score
# 171    Uncharted 4: A Thief's End         7.9
# 289                 Battlefield 1         8.4
# 325     Tom Clancy's The Division         7.0
# 709                 Battlefield 1         8.2
# 1107               Dark Souls III         8.8
# ...                           ...         ...
# 16512                      Ride 2         8.2
# 16513                      Ride 2         7.9
# 16530                  Dungeons 2         7.9
# 16634    Sébastien Loeb Rally Evo         8.2
# 16656            Fast Racing Neo          8.5
#
# [135 rows x 2 columns]

# %%
r.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 135 entries, 171 to 16656
# Series name: Name
# Non-Null Count  Dtype
# --------------  -----
# 135 non-null    object
# dtypes: object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# # Finding toys name with User score more than 9
# #There are 184 toys out of 16717 toys which has an excellent User Score(Rating) of above 9

# %%
e=df[df['User_Score']>9][['Name','User_Score']]
e
# Out:
#                                             Name  User_Score
# 65                             Final Fantasy VII         9.2
# 97                          Super Mario Galaxy 2         9.1
# 106                                     Tekken 3         9.1
# 110                                 Mario Kart 8         9.1
# 111                      Super Smash Bros. Melee         9.1
# ...                                          ...         ...
# 16230                  Monster Rancher Advance 2         9.4
# 16355                                    Deus Ex         9.3
# 16433  Greg Hastings' Tournament Paintball Max'd         9.2
# 16550                Wade Hixton's Counter Punch         9.5
# 16631                              Karnaaj Rally         9.5
#
# [184 rows x 2 columns]

# %%
e.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 184 entries, 65 to 16631
# Series name: Name
# Non-Null Count  Dtype
# --------------  -----
# 184 non-null    object
# dtypes: object(1)
# memory usage: 2.9+ KB

# %% [markdown]
# # Finding which Type(Genre) of Toys has higher user scores
# #Analysis: Action(Genre) toys has the highest number of user scores and it is best in quality.

# %%
df.groupby("Genre")['User_Score'].sum()
# Out:
# Genre
# Action          12908.9
# Adventure        2139.9
# Fighting         2913.7
# Misc             2993.7
# Platform         3125.0
# Puzzle            918.4
# Racing           4510.2
# Role-Playing     5661.3
# Shooter          6506.7
# Simulation       2454.3
# Sports           7678.2
# Strategy         2268.8
# Name: User_Score, dtype: float64

# %% [markdown]
# # Graphical representation of European Union sales as per Toys types(Genre) using Bar plot.
# #Action toys has the highest number of sales in European. Union

# %%
df.groupby("Genre")["EU_Sales"].sum().plot(kind="bar")
plt.show()

# %% [markdown]
# # Finding maximum number of sales of different countries in a single year

# %%
L=df.groupby("Year_of_Release")[['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']].sum()
L.max()
# Out:
# NA_Sales        348.69
# EU_Sales        187.94
# JP_Sales         73.74
# Other_Sales      81.42
# Global_Sales    671.79
# dtype: float64

# %% [markdown]
# # Finding Yearly total sales earnings(amount) for every year in different countries

# %%
h=df.groupby("Year_of_Release")[['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']].sum()
h
# Out:
#                  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Year_of_Release
# 1980.0              10.59      0.67      0.00         0.12         11.38
# 1981.0              33.40      1.96      0.00         0.32         35.77
# 1982.0              26.92      1.65      0.00         0.31         28.86
# 1983.0               7.76      0.80      8.10         0.14         16.79
# 1984.0              33.28      2.10     14.27         0.70         50.36
# 1985.0              33.73      4.74     14.56         0.92         53.94
# 1986.0              12.50      2.84     19.81         1.93         37.07
# 1987.0               8.46      1.41     11.63         0.20         21.74
# 1988.0              23.87      6.59     15.76         0.99         47.22
# 1989.0              45.15      8.44     18.36         1.50         73.45
# 1990.0              25.46      7.63     14.88         1.40         49.39
# 1991.0              12.76      3.95     14.78         0.74         32.23
# ...

# %% [markdown]
# # Finding total nuber of global sales in the year 2016
# #The total nuber of global sales in the year 2016 is 130 Crore

# %%
C=df.groupby("Year_of_Release")

# %%
D=C.get_group(2016)["Global_Sales"].sum()
D
# Out:
# 130.1

# %% [markdown]
# # Finding total nuber of Japan sales in the year 2015
# #The total nuber of japan sales in the year 2015 is 34.09 Crore

# %%
Q=C.get_group(2015)["JP_Sales"].sum()
Q
# Out:
# 34.09

# %%
The total nuber of global sales in the year 2016 is 130 Crore
